# %%
import pandas as pd
import json
from pyserini.search.lucene import LuceneSearcher
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.corpus import stopwords

# %%
# PREPROCESSING Query
stop_words = set(stopwords.words('indonesian'))

factory = StemmerFactory()
stemmer = factory.create_stemmer()

def stem_tokens(tokens):
    return [stemmer.stem(token) for token in tokens]

def preprocess_query(text):
    text = text.lower()
    tokens = [word for word in text.split() if word not in stop_words]
    tokens = stem_tokens(tokens)
    return " ".join(tokens)

# %%
def display_results(query, hits, df):
    print(f"\nQuery: {query}")

    if not hits:
        print("Tidak ada dokumen yang sesuai.")
        return pd.DataFrame()

    results_with_scores = []
    for i, hit in enumerate(hits, start=1):
        # Parse JSON asli dari dokumen (karena pakai --storeRaw)
        try:
            raw = json.loads(hit.raw)
            docid = str(raw.get("id", hit.docid))  # fallback ke docid internal
        except Exception:
            docid = hit.docid

        # Cari di DataFrame
        matching_row = df[df["id"].astype(str) == docid].copy()

        if not matching_row.empty:
            matching_row["score"] = hit.score
            matching_row["rank"] = i
            matching_row["query"] = query
            results_with_scores.append(matching_row)

            # Print ringkas
            print(f"{i}. {matching_row.iloc[0]['title']} (Score: {hit.score:.4f})")
        else:
            print(f"{i}. [ID {docid}] tidak ditemukan di DataFrame (Score: {hit.score:.4f})")

    if results_with_scores:
        return pd.concat(results_with_scores, ignore_index=True)
    else:
        print("No matching documents found in DataFrame.")
        return pd.DataFrame()

# %%
df = pd.read_json("json-file/docs.jsonl", lines=True)

# Gunakan index hasil pyserini.index
searcher = LuceneSearcher("my_index")

# Daftar query
queries = [
    "gemini ai",
    "laptop gaming wajib dibeli",
    "cara agar tidak di hack",
    "teknologi canggih sekarang",
    "komputer terbaik",
    "mobile legend"
]

all_results = []

for q in queries:
    processed_q = preprocess_query(q)   # <<< preprocessing dulu
    hits = searcher.search(processed_q, k=10)
    result_df = display_results(q, hits, df)  # tetap tampilkan query asli
    if not result_df.empty:
        all_results.append(result_df)
# Out:
# Query: gemini ai
# 1. viral foto polaroid gemini ai bareng medsos bikin contoh prompt (Score: 3.1467)
# 2. google limit hari gemini ai gratis ai pro ai ultra (Score: 3.1460)
# 3. gemini ai suntik google drive gambar (Score: 3.1302)
# 4. viral miniatur ai foto medsos buat via gemini (Score: 3.1248)
# 5. viral foto polaroid gemini ai orang tua tiada pakai prompt (Score: 3.1212)
# 6. google sulap chrome browser gemini ai 10 fitur canggih (Score: 3.1140)
# 7. 8 prompt foto polaroid gemini ai idol kpop tinggal pilih copas (Score: 3.0935)
# 8. fitur google docs teks ubah audio ai (Score: 3.0927)
# 9. foto polaroid gemini ai peluk idol kpop viral prompt buat (Score: 3.0848)
# 10. bikin miniatur ai gerak contoh prompt tarik coba (Score: 3.0809)
#
# Query: laptop gaming wajib dibeli
# 1. 6 timbang beli laptop chromebook (Score: 4.9612)
# 2. 10 beda laptop chromebook windows pertimbangankan beli (Score: 4.7194)
# 3. 6 bikin chromebook batas (Score: 4.6599)
# 4. laptop chromebook beda laptop windows (Score: 4.6577)
# 5. anak sawer tiktoker rp 400 juta orangtua refund (Score: 4.4525)
# 6. jajal langsung legion 5i 2025 main gim aaa bikin konten hasil (Score: 3.8233)
# 7. tilik lenovo legion 7i 16iax10 laptop gaming premium workstation profesional (Score: 3.8117)
# 8. laptop gaming lenovo legion pro 7 luncur prosesor ryzen 9000 hx (Score: 3.7828)
# 9. beda laptop chromebook windows (Score: 3.7520)
# 10. main game pakai laptop lenovo legion stasiun mrt bundar hi (Score: 3.7499)
#
# Query: cara agar tidak di hack
# 1. guna iphone wajib cek notif tanda hp dihack (Score: 2.8183)
# 2. google 25 miliar guna gmail ganti password (Score: 2.7386)
# 3. kena hack aman akun whatsapp (Score: 2.7386)
# 4. makna warna pink hijau 178 tuntut rakyat viral medsos (Score: 2.5464)
#
# Query: teknologi canggih sekarang
# 1. deret canggih mitsubishi destinator bikin jalan keluarga nyaman (Score: 2.3920)
# 2. samsung kembang kamera zoom canggih hp galaxy (Score: 2.2266)
# 3. psn vs dunia strategi satelit ri gempur teknologi global (Score: 2.0237)
# 4. masuk ri canggih kamera huawei pura 80 series (Score: 1.9705)
# 5. openai bikin chatgpt ramah remaja aman ketat (Score: 1.9629)
# 6. xiaomi 17 pro desain belakang iphone canggih (Score: 1.9517)
# 7. as cabut izin impor alat chip samsung sk hynix china (Score: 1.9484)
# 8. apple rilis 3 smartwatch watch ultra 3 watch 3 watch series 11 (Score: 1.9159)
# 9. tablet serbaguna fitur ai canggih resmi hadir indonesia spesifikasi harga honor pad 10 (Score: 1.8480)
# 10. adu canggih gpt5 vs gemini 25 flash gambar jakarta realistis (Score: 1.8193)
#
# Query: komputer terbaik
# 1. china bikin chip komputer 1000 triliun kencang superkomputer kuat (Score: 3.6995)
# 2. komputer lawas imac g3 lego butuh 700 keping (Score: 2.8736)
# 3. beda laptop chromebook windows (Score: 2.8183)
# 4. ai ramal anggur besarbesaran (Score: 2.7717)
# 5. microsoft setop dukung office 2016 2019 (Score: 2.7298)
# 6. phk ribu orang ceo microsoft tenang karyawan (Score: 2.6631)
# 7. bos lenovo ai kuat super manusia (Score: 2.5870)
# 8. ganti background zoom android iphone laptop (Score: 2.3837)
# 9. google gratis vids aplikasi edit video tenaga ai (Score: 2.2473)
# 10. ios 26 unduh 2 update fiturfiturnya (Score: 2.2452)
#
# Query: mobile legend
# 1. mobile legends 2118 bawa update besarbesaran hero obsidia gameplay imbang (Score: 5.0004)
# 2. jadwal mobile legends mpl s16 alter ego esports vs evos esports (Score: 4.6541)
# 3. jadwal mpl s16 pekan derbi klasik evos esports vs rrq (Score: 4.5659)
# 4. hasil mobile legends mpl s16 minggu onic esports kalah (Score: 4.4375)
# 5. jadwal mpl id s16 week 4 navi vs onic evos vs dewa united (Score: 4.3036)
# 6. jadwal mobile legends mpl s16 sempat rrq poin penuh (Score: 3.9570)
# 7. jadwal mpl s16 sabtu 20 september rrq hoshi vs dewa united esports laga buka (Score: 3.8839)
# 8. jadwal mpl id s16 week 5 evos ketemu onic (Score: 3.8602)
# 9. jadwal mpl s16 pekan laga onic esports vs rrq hoshi (Score: 3.8135)
# 10. hasil tanding klasemen mpl s16 pekan tiga onic esports kalah (Score: 3.7235)

# %%
if all_results:
    combined = pd.concat(all_results, ignore_index=True)

    # Pilih hanya kolom sesuai permintaan + query
    output_df = combined[["id", "title", "date", "score", "rank", "query"]]

    print("\n=== Semua Hasil Gabungan ===")
    display(output_df)

    # Opsional: simpan ke Excel
    output_df.to_excel("hasil-query/search_results.xlsx", engine="openpyxl")
    #print("\nSemua hasil pencarian disimpan ke search_results.xlsx")
else:
    print("Tidak ada hasil yang ditemukan untuk semua query.")
# Out:
# === Semua Hasil Gabungan ===
#      id                                              title  \
# 0   170  viral foto polaroid gemini ai bareng medsos bi...
# 1   277  google limit hari gemini ai gratis ai pro ai u...
# 2   496               gemini ai suntik google drive gambar
# 3   316      viral miniatur ai foto medsos buat via gemini
# 4   168  viral foto polaroid gemini ai orang tua tiada ...
# 5    25  google sulap chrome browser gemini ai 10 fitur...
# 6   229  8 prompt foto polaroid gemini ai idol kpop tin...
# 7   490               fitur google docs teks ubah audio ai
# 8   236  foto polaroid gemini ai peluk idol kpop viral ...
# 9   268   bikin miniatur ai gerak contoh prompt tarik coba
# 10  314                   6 timbang beli laptop chromebook
# 11  248  10 beda laptop chromebook windows pertimbangan...
# 12  143                           6 bikin chromebook batas
# 13  363              laptop chromebook beda laptop windows
# 14  320    anak sawer tiktoker rp 400 juta orangtua refund
# 15   60  jajal langsung legion 5i 2025 main gim aaa bik...
# 16   78  tilik lenovo legion 7i 16iax10 laptop gaming p...
# 17  352  laptop gaming lenovo legion pro 7 luncur prose...
# 18  328                     beda laptop chromebook windows
# 19  508  main game pakai laptop lenovo legion stasiun m...
# 20   99        guna iphone wajib cek notif tanda hp dihack
# 21  330         google 25 miliar guna gmail ganti password
# 22  454                       kena hack aman akun whatsapp
# 23  422  makna warna pink hijau 178 tuntut rakyat viral...
# 24  667  deret canggih mitsubishi destinator bikin jala...
# 25  311      samsung kembang kamera zoom canggih hp galaxy
# 26  579  psn vs dunia strategi satelit ri gempur teknol...
# 27  695      masuk ri canggih kamera huawei pura 80 series
# 28   75       openai bikin chatgpt ramah remaja aman ketat
# 29  509       xiaomi 17 pro desain belakang iphone canggih
# 30  356  as cabut izin impor alat chip samsung sk hynix...
# 31  259  apple rilis 3 smartwatch watch ultra 3 watch 3...
# 32  367  tablet serbaguna fitur ai canggih resmi hadir ...
# 33  286  adu canggih gpt5 vs gemini 25 flash gambar jak...
# 34  284  china bikin chip komputer 1000 triliun kencang...
# 35  437       komputer lawas imac g3 lego butuh 700 keping
# 36  328                     beda laptop chromebook windows
# 37  666                       ai ramal anggur besarbesaran
# 38  484            microsoft setop dukung office 2016 2019
# 39  568       phk ribu orang ceo microsoft tenang karyawan
# 40  230                   bos lenovo ai kuat super manusia
# 41  457        ganti background zoom android iphone laptop
# 42  497   google gratis vids aplikasi edit video tenaga ai
# 43  125                ios 26 unduh 2 update fiturfiturnya
# 44   29  mobile legends 2118 bawa update besarbesaran h...
# 45  487  jadwal mobile legends mpl s16 alter ego esport...
# 46  204  jadwal mpl s16 pekan derbi klasik evos esports...
# 47  450  hasil mobile legends mpl s16 minggu onic espor...
# 48  638  jadwal mpl id s16 week 4 navi vs onic evos vs ...
# 49  162  jadwal mobile legends mpl s16 sempat rrq poin ...
# 50   22  jadwal mpl s16 sabtu 20 september rrq hoshi vs...
# 51  513          jadwal mpl id s16 week 5 evos ketemu onic
# 52  375  jadwal mpl s16 pekan laga onic esports vs rrq ...
# 53  313  hasil tanding klasemen mpl s16 pekan tiga onic...
#
#                              date     score  rank                       query
# 0       Minggu, 14 September 2025  3.146700     1                   gemini ai
# 1        Selasa, 9 September 2025  3.146000     2                   gemini ai
# 2          Jumat, 29 Agustus 2025  3.130200     3                   gemini ai
# 3         Senin, 8 September 2025  3.124800     4                   gemini ai
# 4       Minggu, 14 September 2025  3.121200     5                   gemini ai
# 5        Sabtu, 20 September 2025  3.114000     6                   gemini ai
# 6        Kamis, 11 September 2025  3.093500     7                   gemini ai
